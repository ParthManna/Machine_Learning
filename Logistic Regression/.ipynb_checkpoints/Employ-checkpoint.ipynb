# %%
import pandas as pd

# %%
df = pd.read_csv('CSV_file/HR_comma_sep.csv')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up visual styling
sns.set(style="whitegrid")

# Plot the impact of salary on employee retention
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='salary', hue='left', palette='Set1')
plt.title('Impact of Salary on Employee Retention')
plt.xlabel('Salary Category')
plt.ylabel('Number of Employees')
plt.legend(title='Left the Company', loc='upper right')
plt.show()

# %%
# Plot the correlation between department and employee retention
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Department', hue='left', palette='Set2')
plt.title('Correlation Between Department and Employee Retention')
plt.xlabel('Department')
plt.ylabel('Number of Employees')
# plt.xticks(rotation=45)
plt.legend(title='Left the Company', loc='upper right')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Prepare the data for modeling

# Convert categorical variables into dummy variables (one-hot encoding)
df_encoded = pd.get_dummies(df, columns=['salary', 'Department'], drop_first=True).astype(int)
print(df_encoded)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                       0                0               2
# 1                       0                0               5
# 2                       0                0               7
# 3                       0                0               5
# 4                       0                0               2
# ...                   ...              ...             ...
# 14994                   0                0               2
# 14995                   0                0               2
# 14996                   0                0               2
# 14997                   0                0               6
# 14998                   0                0               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
# Features and target variable
X = df_encoded.drop('left', axis=1)
y = df_encoded['left']

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_scaled
X_test_scaled
# Out:
# array([[-0.09193801, -0.13466333,  0.96885654, ..., -0.62261971,
#         -0.41397004, -0.46703614],
#        [-0.09193801, -0.13466333, -0.64934658, ..., -0.62261971,
#         -0.41397004, -0.46703614],
#        [-0.09193801, -0.13466333, -0.64934658, ...,  1.60611684,
#         -0.41397004, -0.46703614],
#        ...,
#        [-0.09193801, -0.13466333, -0.64934658, ..., -0.62261971,
#         -0.41397004, -0.46703614],
#        [-0.09193801, -0.13466333,  0.96885654, ...,  1.60611684,
#         -0.41397004, -0.46703614],
#        [-0.09193801, -0.13466333, -0.64934658, ..., -0.62261971,
#         -0.41397004, -0.46703614]])

# %%
# Build the logistic regression model
model = LogisticRegression(max_iter=1000)
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Make predictions on the test set
y_pred = model.predict(X_test_scaled)

# %%
# Measure the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# 0.7595555555555555
